# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.plot([1,2,3],[6,7,8])
plt.show()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.plot([1,2,3],[6,7,8])
plt.title("matplot data")
plt.ylabel("y")
plt.xlabel("x")
plt.show()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import style
style.use("ggplot")
x=[1000,200,3000]
y=[1000,110,12000]
x1=[100,200,300]
y1=[1000,2000,3000]
# plt.title("double dta")
# plt.xlabel("x")
# plt.ylabel("y")
plt.scatter(x,y,label="first",linewidth=3)
plt.plot(x1,y1,label="second")
plt.legend()
plt.show()
